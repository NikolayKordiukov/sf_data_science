# %% [markdown]
# ### Использование метода Лагранжа
# Прямоугольный параллелепипед имеет объём 1м3. Чему равна минимальная площадь его поверхности?

# %%
from sympy import *
# a,b,c - стороны параллелепипед
a,b,c,w=symbols(' a b c w' )

g = 2*a*b + 2*c*a + 2*b*c
print('Целевая функция для аргументов a,b,c :\n f = ', g)

q = a*b*c - 1
print('Функция ограничений: ', q,'= 0')

f = (2*a*b + 2*c*a + 2*b*c) + w*(a*b*c - 1) 
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fc = f.diff(c)
print('df/dc =',fc,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw,fc],a,b,c,w)
#print('Стационарная точка M(x,y,z):\n',float(sols[a]),',',float(sols[b]),',',float(sols[c]))
print('Минимальная площадь поверхности =',2*sols[0][0]*sols[0][1] + 2*sols[0][1]*sols[0][2] + 2*sols[0][2]*sols[0][0])


#
#Целевая функция для аргументов a,b,c :
# f =  2*a*b + 2*a*c + 2*b*c
#Функция ограничений:  a*b*c - 1 = 0
#Функция Лагранжа :
  #2*a*b + 2*a*c + 2*b*c + w*(a*b*c - 1)
#df/da = b*c*w + 2*b + 2*c = 0
#df/db = a*c*w + 2*a + 2*c = 0
#df/dc = a*b*w + 2*a + 2*b = 0
#df/dw = a*b*c - 1 = 0
#Минимальная площадь поверхности = 6
# Out:
# Целевая функция для аргументов a,b,c :
#  f =  2*a*b + 2*a*c + 2*b*c
# Функция ограничений:  a*b*c - 1 = 0
# Функция Лагранжа :
#   2*a*b + 2*a*c + 2*b*c + w*(a*b*c - 1)
# df/da = b*c*w + 2*b + 2*c = 0
# df/db = a*c*w + 2*a + 2*c = 0
# df/dc = a*b*w + 2*a + 2*b = 0
# df/dw = a*b*c - 1 = 0
# Минимальная площадь поверхности = 6

# %% [markdown]
# У нас есть два станка для производства пластиковых упаковок. Станки разных моделей, поэтому при их использовании получаются разные издержки, зависящие от произведённых упаковок и выражаемые следующими функциями:
#
# Здесь `a` — это количество упаковок, произведённых на первом станке, а `b` — количество упаковок, произведённых на втором станке.
#
# Нам заказали 200 упаковок. Мы хотим выполнить заказ, минимизировав расходы на изготовление товаров. Чтобы узнать, как мы можем сэкономить, необходимо решить задачу оптимизации.

# %%
from sympy import *
a,b,w=symbols(' a b w' )
g = 3*a**2 + a + 4*b + 5*b**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 200
print('Функция ограничений: ', q,'= 0')
f = 3*a**2 + a + 4*b + 5*b**2 + w*(a + b - 200)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw],a,b,w)
print('Стационарная точка M(x,y):\n',float(sols[a]),',',float(sols[b]))

#Целевая функция для аргументов a и b :
#f =  3*a**2 + a + 5*b**2 + 4*b
#Функция ограничений:  a + b - 200 = 0
#Функция Лагранжа :
#3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
#df/da = 6*a + w + 1 = 0
#df/db = 10*b + w + 4 = 0
#df/dw = a + b - 200 = 0
#Стационарная точка M(x,y):
#125.1875 , 74.8125
# Out:
# Целевая функция для аргументов a и b :
#  f =  3*a**2 + a + 5*b**2 + 4*b
# Функция ограничений:  a + b - 200 = 0
# Функция Лагранжа :
#   3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
# df/da = 6*a + w + 1 = 0
# df/db = 10*b + w + 4 = 0
# df/dw = a + b - 200 = 0
# Стационарная точка M(x,y):
#  125.1875 , 74.8125

# %% [markdown]
# Представьте, что вы решаете задачу классификации методом опорных векторов и хотите оценить расстояние от объекта до разделяющей прямой с помощью метода Лагранжа.
# Если объект имеет координаты `(2;1)`, а прямая задана уравнением `x+y=1`, то каким будет квадрат расстояния от этого объекта до прямой?

# %%
from sympy import *
a,b,w=symbols(' a b w' )
g = (a-2)**2 + (b-1)**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 1
print('Функция ограничений: ', q,'= 0')
f = (a-2)**2 + (b-1)**2 + w*(a + b - 1)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw],a,b,w)
print('Стационарная точка M(x,y):\n',float(sols[a]),',',float(sols[b]))
print('Квадрат расстояния =',(sols[a]-2)**2 + (sols[b]-1)**2)
# Out:
# Целевая функция для аргументов a и b :
#  f =
#  (a - 2)**2 + (b - 1)**2
# Функция ограничений:  a + b - 1 = 0
# Функция Лагранжа :
#   w*(a + b - 1) + (a - 2)**2 + (b - 1)**2
# df/da = 2*a + w - 4 = 0
# df/db = 2*b + w - 2 = 0
# df/dw = a + b - 1 = 0
# Стационарная точка M(x,y):
#  1.0 , 0.0
# Квадрат расстояния = 2

# %% [markdown]
# Мы разобрали задачи, в которых ограничения выглядели, как равенства. Но бывают и исключительные случаи, в которых ограничения заданы в виде неравенств.
#
# Рассмотрим решение задачи с таким ограничением на примере ↓
#
# Длина забора — 20 метров. Какова максимальная площадь прямоугольного участка, который можно огородить? Хотя бы одна из сторон прямоугольника должна быть не меньше 6.

# %%
# Импортируем все необходимые функции из библиотеки SymPy
from sympy import init_printing, solve, symbols

# Подключаем аккуратный вывод формул
init_printing()

# Создаём переменные
x1, x2, x1_tilde, lambda1, lambda2 = symbols(
    "x_1 x_2 xtilde_2 \lambda_1 \lambda_2", real=True
)

# Пишем систему уравнений для переменных
dLdx1 = -x2 + lambda1 - lambda2
dLdx2 = -x1 + lambda1
dLdx1_tilde = 2 * lambda2 * x1_tilde
dLdlambda1 = x1 + x2 - 10
dLdlambda2 = -x1 + 6 + x1_tilde**2

# Решаем систему уравнений с помощью функции solve
solution = solve(
    [dLdx1, dLdx2, dLdx1_tilde, dLdlambda1, dLdlambda2],
    x1,
    x2,
    x1_tilde,
    lambda1,
    lambda2,
)

print(solution)
#[(6, 4, 0, 6, 2)]
#Получаем, что значения  x1 и x2  равны 6 и 4 соответственно, а значит максимальная площадь равна 24.
# Out:
# [(6, 4, 0, 6, 2)]

# %%
# для решения градиента

from sympy import *
w0,w1=symbols(' w0 w1 ' )

f = (2.1-w0-w1)**2 + (2.9-w0-3*w1)**2 + (4.1-w0-5*w1)**2
print('Исходная функция :\n ',f)
fw0 = f.diff(w0)
print('df/dw0 =',fw0,'= 0')
fw1 = f.diff(w1)
print('df/dw1 =',fw1,'= 0')

sols = solve([fw0,fw1],w0,w1)
print('Стационарная точка M(x,y):\n',float(sols[w0]),',',float(sols[w1]))
# Out:
# Исходная функция :
#   4.41*(-0.476190476190476*w0 - 0.476190476190476*w1 + 1)**2 + 9*(-w0/3 - w1 + 0.966666666666667)**2 + 25*(-w0/5 - w1 + 0.82)**2
# df/dw0 = 6.0*w0 + 18.0*w1 - 18.2 = 0
# df/dw1 = 18.0*w0 + 70.0*w1 - 62.6 = 0
# Стационарная точка M(x,y):
#  1.5333333333333334 , 0.5

# %% [markdown]
# Пусть дан одномерный массив `f = np.array([8, 2, 8, 3, 5, 6, 5, 15])`.
#
# Вычислите градиент массива , увеличив шаг сетки в семь раз, и укажите значение седьмого элемента массива получившихся градиентов  (порядок элементов начинается с 0).

# %%
import numpy as np

f = np.array([8, 2, 8, 3, 5, 6, 5, 15])
 
np.gradient(f,7)[7]

#1.42857142857143
# Out:
# 1.4285714285714286

# %% [markdown]
# Допустим, вы хотите произвести некоторое количество товара, которое зависит от часов работы двух ключевых сотрудников следующим образом: `f(x,y) = x**2 + 2*y**2`
#
# где x — время работы 1-ого сотрудника,  y  — время работы 2-ого сотрудника.
#
# Однако вы должны оплатить этим сотрудникам ровно 20 часов работы в сумме, то есть: `x + y = 20`
#
# Какое наибольшее количество товаров вы сможете произвести в таком случае?
#
# Помните, что количество часов работы должно быть целым, поэтому, прежде чем вычислять итоговый результат, округлите часы работы до целого.

# %%
from sympy import *
a,b,w=symbols(' a b w' )
g = a**2 + 2*b**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 20
print('Функция ограничений: ', q,'= 0')
f =  a**2 + 2*b**2 + w*(a + b - 20)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw],a,b,w)
print('Стационарная точка M(x,y):\n',float(sols[a]),',',float(sols[b]))
print(f'Максимальное количество товаров: {g.subs([(a, round(float(sols[a]))), (b, round(float(sols[b])))])}')
# Out:
# Целевая функция для аргументов a и b :
#  f =  a**2 + 2*b**2
# Функция ограничений:  a + b - 20 = 0
# Функция Лагранжа :
#   a**2 + 2*b**2 + w*(a + b - 20)
# df/da = 2*a + w = 0
# df/db = 4*b + w = 0
# df/dw = a + b - 20 = 0
# Стационарная точка M(x,y):
#  13.333333333333334 , 6.666666666666667
# Максимальное количество товаров: 267

# %% [markdown]
# На текстильной фабрике есть 750 метров хлопка и 1000 метров полиэстера.
#
# Для изготовления свитшота требуется 1 метр хлопка и 2 метра полиэстера, для изготовления рубашки — 1.5 метра хлопка и 1 метр полиэстера.
#
# Свитшот можно продать за 30 евро, а рубашку — за 24 евро.
#
# Какое суммарное количество свитшотов и рубашек максимизирует возможную прибыль?

# %%
from sympy import *
a,b,c,d=symbols(' a b c d' )
g = 30*a + 24*b
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + 1.5*b - 750
print('Функция ограничений q: ', q,'= 0')
r = 2*a + b - 1000
print('Функция ограничений r: ', r,'= 0')
f =  -(30*a + 24*b) + c*(a + 1.5*b - 750)+d*(2*a + b - 1000)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fc = f.diff(c)
print('df/dc =',fc,'= 0')
fd = f.diff(d)
print('df/dd =',fd,'= 0')
sols = solve([fa,fb,fc,fd],a,b,c,d)
print('Стационарная точка M(a,b,c,d):\n',float(sols[a]),',',float(sols[b]),',',float(sols[c]),',',float(sols[d]))
print(f'Максимальная прибыль: {g.subs([(a, round(float(sols[a]))), (b, round(float(sols[b])))])}')
print(f'Суммарное количество рубашек и свитшотов: {round(float(sols[a]))+round(float(sols[b]))}')
# Out:
# Целевая функция для аргументов a и b :
#  f =  30*a + 24*b
# Функция ограничений q:  a + 1.5*b - 750 = 0
# Функция ограничений r:  2*a + b - 1000 = 0
# Функция Лагранжа :
#   -30*a - 24*b + c*(a + 1.5*b - 750) + d*(2*a + b - 1000)
# df/da = c + 2*d - 30 = 0
# df/db = 1.5*c + d - 24 = 0
# df/dc = a + 1.5*b - 750 = 0
# df/dd = 2*a + b - 1000 = 0
# Стационарная точка M(a,b,c,d):
#  375.0 , 250.0 , 9.0 , 10.5
# Максимальная прибыль: 17250
# Суммарное количество рубашек и свитшотов: 625

# %% [markdown]
# Магазин спортивных товаров получает прибыль в размере 6 долларов с каждого проданного футбольного мяча и 5.5 долларов — с бейсбольного.
#
# Каждый месяц магазин продаёт от 35 до 45 футбольных мячей и от 40 до 55 бейсбольных.
#
# Известно, что в этом месяце у магазина есть в общей сложности 80 мячей.
#
# Какую максимальную прибыль в этом месяце может получить магазин от продажи мячей?

# %%
from sympy import *
a,b,c,d,e,h,i,a_tilde,b_tilde,a_tilde2,b_tilde2=symbols(' a b c d e h i a_tilde b_tilde a_tilde2 b_tilde2')
g = 6*a + 5.5*b
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 80
print('Функция ограничений q: ', q,'= 0')



f =  -(6*a + 5.5*b) + c*(a + b - 80) + d*(-a + 35 + a_tilde**2) + e*(-b + 40 + b_tilde**2) + h*(a - 45 + a_tilde2**2) + i*(b - 55 + b_tilde2**2)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')

fc = f.diff(c)
fd = f.diff(d)
fe = f.diff(e)
fa_tilde = f.diff(a_tilde)
fb_tilde = f.diff(b_tilde)
fh = f.diff(h)
fi = f.diff(i)
fa_tilde2 = f.diff(a_tilde2)
fb_tilde2 = f.diff(b_tilde2)

sols = solve([fa,fb,fc,fd,fe,fh,fi,fa_tilde,fb_tilde,fa_tilde2,fb_tilde2],a,b,c,d,e,h,i,a_tilde,b_tilde,a_tilde2,b_tilde2)

sols
# Out:
# Целевая функция для аргументов a и b :
#  f =  6*a + 5.5*b
# Функция ограничений q:  a + b - 80 = 0
# Функция Лагранжа :
#   -6*a - 5.5*b + c*(a + b - 80) + d*(-a + a_tilde**2 + 35) + e*(-b + b_tilde**2 + 40) + h*(a + a_tilde2**2 - 45) + i*(b + b_tilde2**2 - 55)
# df/da = c - d + h - 6 = 0
# df/db = c - e + i - 5.5 = 0
# [(25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   0.0,
#   0.0,
#   -0.500000000000000,
#   -3.16227766016838*I,
#   -3.87298334620742,
#   -4.47213595499958,
#   0.0),
#  (25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   0.0,
#   0.0,
#   -0.500000000000000,
#   -3.16227766016838*I,
#   3.87298334620742,
#   -4.47213595499958,
#   0.0),
#  (25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   0.0,
#   0.0,
#   -0.500000000000000,
#   -3.16227766016838*I,
#   -3.87298334620742,
#   4.47213595499958,
#   0.0),
#  (25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   0.0,
# ...

# %%
from sympy import *
a,b,c,h,i,a_tilde2,b_tilde2=symbols(' a b c h i a_tilde2 b_tilde2')
g = 6*a + 5.5*b
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 80
print('Функция ограничений q: ', q,'= 0')



f =  -(6*a + 5.5*b) + c*(a + b - 80) + h*(a - 45 + a_tilde2**2) + i*(b - 55 + b_tilde2**2)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')

fc = f.diff(c)

fh = f.diff(h)
fi = f.diff(i)
fa_tilde2 = f.diff(a_tilde2)
fb_tilde2 = f.diff(b_tilde2)

sols = solve([fa,fb,fc,fh,fi,fa_tilde2,fb_tilde2],a,b,c,h,i,a_tilde2,b_tilde2)
#print('Стационарная точка M(a,b,c):\n',float(sols[a]),',',float(sols[b]),',',float(sols[c]))
#print(f'Максимальная прибыль: {g.subs([(a, round(float(sols[a]))), (b, round(float(sols[b])))])}')
#print(f'Суммарное количество футбольных и бейсбольных мячей: {round(float(sols[a]))+round(float(sols[b]))}')
sols
# Out:
# Целевая функция для аргументов a и b :
#  f =  6*a + 5.5*b
# Функция ограничений q:  a + b - 80 = 0
# Функция Лагранжа :
#   -6*a - 5.5*b + c*(a + b - 80) + h*(a + a_tilde2**2 - 45) + i*(b + b_tilde2**2 - 55)
# df/da = c + h - 6 = 0
# df/db = c + i - 5.5 = 0
# [(25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   -0.500000000000000,
#   -4.47213595499958,
#   0.0),
#  (25.0000000000000,
#   55.0000000000000,
#   6.00000000000000,
#   0.0,
#   -0.500000000000000,
#   4.47213595499958,
#   0.0),
#  (45.0000000000000,
#   35.0000000000000,
#   5.50000000000000,
#   0.500000000000000,
#   0.0,
#   0.0,
#   -4.47213595499958),
#  (45.0000000000000,
#   35.0000000000000,
#   5.50000000000000,
#   0.500000000000000,
#   0.0,
#   0.0,
#   4.47213595499958)]
